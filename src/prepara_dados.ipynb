# %% [markdown]
# # Georreferenciamento e análise de informações do banco de sentenças do TJSP
#
# ### José Eduardo de Souza Pimentel - 2026

# %%
# Importações necessárias

import os
import json
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
from dotenv import load_dotenv
from openai import OpenAI

# %%
# Carrega variáveis de ambiente

load_dotenv()

OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')

# %%
# Configurações

MODELO = "gpt-5-nano" #"gpt-5-mini"
PATH_SENTENCAS = "dados"
MAX_INTERACOES = 10
CSV_SENTENCAS = 'dados\\sentencas.csv'
CSV_SENTENCAS_ANALISADAS = 'dados\\sentencas_analisadas.csv'
CSV_SENTENCAS_COM_ENDERECOS = 'dados\\sentencas_com_enderecos.csv'
CSV_SENTENCAS_GEORREFERENCIADAS = 'dados\\sentencas_georreferenciadas.csv'

# Limites geográficos (cantos do retângulo)
PONTO_1 = (-22.59505, -47.87594)
PONTO_2 = (-22.86262, -47.41858)

# %%
# Parametrização da requisição ao TJSP

PARAMS_TJSP = params = {
    "conversationId": "",
    "dadosConsulta.pesquisaLivre": "",
    "tipoNumero": "UNIFICADO",
    "numeroDigitoAnoUnificado": "",
    "foroNumeroUnificado": "",
    "dadosConsulta.nuProcesso": "",
    "dadosConsulta.nuProcessoAntigo": "",
    "classeTreeSelection.values": "",
    "classeTreeSelection.text": "",
    "assuntoTreeSelection.values": "3608",
    "assuntoTreeSelection.text": "Tráfico de Drogas e Condutas Afins",
    "agenteSelectedEntitiesList": "",
    "contadoragente": "0",
    "contadorMaioragente": "0",
    "cdAgente": "",
    "nmAgente": "",
    "dadosConsulta.dtInicio": "",
    "dadosConsulta.dtFim": "",
    "varasTreeSelection.values": "451-10,451-8,451-7101,451-7084,451-7094,451-7095,451-9,451-5623",
    "varasTreeSelection.text": "8 Registros selecionados",
    "dadosConsulta.ordenacao": "DESC"
}

# %% [markdown]
# # Download das sentenças

# %%
# Cria uma sessão persistente
session = requests.Session()

# 1a requisição para obter os cookies
response = session.get("https://esaj.tjsp.jus.br/cjpg/pesquisar.do", params=PARAMS_TJSP)

if response.status_code == 200:
    for i in range(1, MAX_INTERACOES + 1):
        pagina = str(i)
        url_pagina = f"https://esaj.tjsp.jus.br/cjpg/trocarDePagina.do?pagina={pagina}&conversationId="

        # Usa a mesma sessão para fazer a requisição
        response = session.get(url_pagina)

        if response.status_code == 200:
            # Salva o conteúdo da página
            with open(f"{PATH_SENTENCAS}/pagina_{pagina}.html", "wb") as file:
                file.write(response.content)
            print(f"Página {pagina} salva com sucesso.")
        else:
            print(f"Erro ao acessar a página {pagina}: {response.status_code}")

        # Intervalo entre requisições
        time.sleep(1)
else:
    print("Erro ao acessar a página inicial.")
# Out:
# Página 1 salva com sucesso.
# Página 2 salva com sucesso.
# Página 3 salva com sucesso.

# %% [markdown]
# # Criação do dataframe

# %%
def extrair_informacoes_html(html_path):
    processos = []
    with open(html_path, "r", encoding="utf-8") as file:
        soup = BeautifulSoup(file, "html.parser")
        textos = soup.find_all(class_="fundocinza1")
        for texto in textos:
            processo = {}
            # Número do Processo
            processo['numero_do_processo'] = texto.find('span', class_='fonteNegrito').text.strip()

            # Classe, Assunto, Magistrado, Comarca, Foro, Vara, Data de Disponibilização
            for row in texto.find_all('tr', class_='fonte'):
                if row.find('strong'):
                    key = row.find('strong').text.strip().replace(':', '').lower().replace(' ', '_')
                    value = row.find('strong').next_sibling.strip()
                    processo[key] = value

            # Sentença
            sentenca_divs = texto.find_all('div', align='justify')
            sentenca = ''
            for div in sentenca_divs:
                span = div.find('span')
                if span:
                    sentenca += span.text.strip() + '\n'
            processo['sentenca'] = sentenca.strip()

            processos.append(processo)

        return processos

# %%
data = []

for filename in os.listdir(PATH_SENTENCAS):
    if filename.endswith(".html"):
        filepath = os.path.join(PATH_SENTENCAS, filename)
        data += (extrair_informacoes_html(filepath))

# Cria o DataFrame
df = pd.DataFrame(data)
df.head(5)
# Out:
#            numero_do_processo                                    classe  \
# 0   1501036-78.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 1   1501473-22.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 2   1501416-04.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 3   1501498-35.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 4   1501733-02.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 5   1501391-93.2022.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 6   1501551-84.2023.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 7   1500825-76.2024.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 8   1501156-92.2023.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 9   1501774-03.2024.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 10  1501429-03.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 11  1501004-73.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 12  1501116-76.2024.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 13  1500518-25.2024.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 14  1500695-86.2024.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 15  1501022-94.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 16  1501896-79.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 17  1501907-11.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 18  1500693-82.2025.8.26.0599       Ação Penal - Procedimento Ordinário
# 19  1501521-78.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 20  1500590-75.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 21  1502144-45.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 22  1501263-68.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 23  1501625-70.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 24  1501925-32.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
#
#                                assunto     comarca                foro  \
# 0   Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 1   Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 2   Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 3   Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 4   Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 5   Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 6   Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 7   Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 8   Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 9   Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 10  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 11  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 12  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 13  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 14  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 15  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 16  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 17  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 18  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 19  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 20  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 21  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 22  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 23  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 24  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
#
#                 vara data_de_disponibilização  \
# 0   4ª Vara Criminal               09/01/2026
# 1   2ª Vara Criminal               09/01/2026
# 2   4ª Vara Criminal               09/01/2026
# 3   1ª Vara Criminal               09/01/2026
# 4   1ª Vara Criminal               08/01/2026
# 5   2ª Vara Criminal               07/01/2026
# 6   3ª Vara Criminal               07/01/2026
# 7   4ª Vara Criminal               05/01/2026
# 8   4ª Vara Criminal               29/12/2025
# 9   3ª Vara Criminal               19/12/2025
# 10  2ª Vara Criminal               18/12/2025
# 11  3ª Vara Criminal               18/12/2025
# 12  3ª Vara Criminal               18/12/2025
# 13  1ª Vara Criminal               17/12/2025
# 14  2ª Vara Criminal               17/12/2025
# 15  3ª Vara Criminal               17/12/2025
# 16  4ª Vara Criminal               17/12/2025
# 17  1ª Vara Criminal               17/12/2025
# 18  2ª Vara Criminal               17/12/2025
# 19  4ª Vara Criminal               17/12/2025
# 20  4ª Vara Criminal               17/12/2025
# 21  2ª Vara Criminal               17/12/2025
# 22  4ª Vara Criminal               17/12/2025
# 23  2ª Vara Criminal               16/12/2025
# 24  1ª Vara Criminal               16/12/2025
#
#                                              sentenca  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6   SENTENÇA\n\nProcesso Digital nº:\t1501551-84.2...
# 7   SENTENÇA\n\nProcesso Digital nº:\t1500825-76.2...
# 8   SENTENÇA\n\nProcesso Digital nº:\t1501156-92.2...
# 9   SENTENÇA\n\nProcesso Digital nº:\t1501774-03.2...
# 10  SENTENÇA\n\nProcesso Digital nº:\t1501429-03.2...
# 11
# 12
# 13  SENTENÇA\n\nProcesso Digital nº:\t1500518-25.2...
# 14
# 15
# 16  SENTENÇA\n\nProcesso Digital nº:\t1501896-79.2...
# 17
# 18
# 19  SENTENÇA\n\nProcesso Digital nº:\t1501521-78.2...
# 20
# 21
# 22  SENTENÇA\n\nProcesso Digital nº:\t1501263-68.2...
# 23
# 24
#
#                                magistrado
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                 Rodrigo Pares Andreucci
# 7           GABRIELA DE ALMEIDA VERGUEIRO
# 8           GABRIELA DE ALMEIDA VERGUEIRO
# 9                 Rodrigo Pares Andreucci
# 10          GABRIELA DE ALMEIDA VERGUEIRO
# 11                                    NaN
# 12                                    NaN
# 13        Ana Claudia Madeira de Oliveira
# 14  Flavia de Cassia Gonzales de Oliveira
# 15                                    NaN
# 16                           Gisela Ruffo
# 17                                    NaN
# 18                                    NaN
# 19          GABRIELA DE ALMEIDA VERGUEIRO
# 20                                    NaN
# 21                                    NaN
# 22                           Gisela Ruffo
# 23  Flavia de Cassia Gonzales de Oliveira
# 24        Ana Claudia Madeira de Oliveira

# %%
# Cria o dataframe com sentenças não vazias e salva em CSV
df_1 = df[(df['sentenca']!='')]
df_1 = df_1.drop_duplicates(subset=['numero_do_processo'], keep='last') # Despreza os processos repetidos
df_1.reset_index(drop=True, inplace=True)
df_1.to_csv(CSV_SENTENCAS, index=False, encoding='utf-8-sig')  # utf-8-sig para compatibilidade com Excel
print(f"Arquivo CSV salvo em: {CSV_SENTENCAS}")
# Out:
# Arquivo CSV salvo em: dados\sentencas.csv

# %% [markdown]
# # Consulta à API OpenAI para análise das sentenças

# %%
SYSTEM_MSG = (
    "Você é assessor jurídico especializado em direito penal. "
    "Responda exclusivamente em JSON válido, sem comentários, com as chaves: "
    "'data_fato', 'quantidade_reus', 'endereco_fato', 'responsavel_prisao', "
    "'modus_operandi_reu', 'alegacao_reu', 'resultado_processo', 'resumo_sentenca'."
)

USER_TEMPLATE = (
    "Analise a sentença a seguir e devolva um objeto JSON contendo as chaves já indicadas."
    "Para a chave 'data_fato' responda apenas com a data do fato (ex.: 24/03/2025)"
    "ou escreva 'Não se aplica'."
    "Para a chave 'quantidade_reus' responda apenas com um número (ex.: 1, 2, 3 etc)"
    "ou escreva 'Não se aplica'."
    "Para a chave 'endereco_fato' responda com o endereço principal do fato "
    "(ex.: rua Alvorada, 123, bairro Jardim Brasília, Piracicaba/SP)."
    "ou escreva 'Não se aplica'."
    "Para a chave 'responsavel_prisao', informe que tipo de agente público realizou a prisão "
    "(ex.: policial militar, policial civil, policial penal, guarda municipal, outros) "
    "ou escreva 'Não se aplica'."
    "Para a chave 'modus_operandi_reu', resuma em até 70 palavras de que forma o tráfico era realizado "
    "ou escreva 'Não se aplica'."
    "Para a chave 'alegacao_reu', resuma em até 70 palavras o que o réu ou os réus alegaram em suas defesas "
    "ou escreva 'Não se aplica'."
    "Para a chave 'resultado_processo', responda 'Procedente', 'Improcedente', 'Parcialmente procedente' "
    "ou escreva 'Não se aplica'."
    "Para a chave 'resumo_sentenca', resuma em até 100 palavras a sentença em sua totalidade."
    "RESTRIÇÕES: para todos os casos, não se refira ao(s) réu(s) pelo nome. Use suas iniciais.\n\n"
    "SENTENÇA:\n\n{sentenca}"
)


client = OpenAI()

def analisar_sentenca_openai(sentenca: str) -> dict:
    """
    Analisa o texto de uma sentença usando modelo da OpenAI
    e retorna os dados extraídos em formato de dicionário Python.
    """

    resposta_api = None

    try:
        response = client.chat.completions.create(
            model=MODELO,
            response_format={"type": "json_object"},  # força o JSON
            messages=[
                {"role": "system", "content": SYSTEM_MSG},
                {"role": "user", "content": USER_TEMPLATE.format(sentenca=sentenca)}
            ]
        )

        if (
            response
            and response.choices
            and response.choices[0].message
            and response.choices[0].message.content
        ):
            resposta_api = response.choices[0].message.content.strip()
        else:
            resposta_api = "Erro: Resposta da API em formato inesperado."
            print(f"Resposta inesperada da API: {response}")

    except Exception as e:
        resposta_api = f"Erro ao processar com OpenAI: {e}"

    return resposta_api

# %%
lista_de_respostas = []
for idx, row in df_1.iterrows():
    resposta_texto = analisar_sentenca_openai(row['sentenca'])  # string retornada pela API
    try:
        analise = json.loads(resposta_texto)  # converte a string JSON para dict
    except Exception as e:
        print(f"Erro ao converter JSON no processo {row['numero_do_processo']}: {e}")
        print("Resposta bruta da API:", resposta_texto)
        # fallback: cria dicionário com valores padrão para não quebrar o pipeline
        analise = {
            "data_fato": "Não se aplica",
            "quantidade_reus": "Não se aplica",
            "endereco_fato": "Não se aplica",
            "responsavel_prisao": "Não se aplica",
            "modus_operandi_reu": "Não se aplica",
            "alegacao_reu": "Não se aplica",
            "resultado_processo": "Não se aplica",
            "resumo_sentenca": "Não se aplica"
        }
    n_processo = row['numero_do_processo']
    print(f"Analisando o processo {n_processo}...")
    lista_de_respostas.append((n_processo, analise))
# Out:
# Analisando o processo 1501551-84.2023.8.26.0599...
# Analisando o processo 1500825-76.2024.8.26.0599...
# Analisando o processo 1501156-92.2023.8.26.0599...
# Analisando o processo 1501774-03.2024.8.26.0599...
# Analisando o processo 1500518-25.2024.8.26.0599...
# Analisando o processo 1501896-79.2025.8.26.0599...
# Analisando o processo 1501366-75.2025.8.26.0599...
# Analisando o processo 1501824-97.2022.8.26.0599...
# Analisando o processo 1501966-67.2023.8.26.0599...
# Analisando o processo 1501612-42.2023.8.26.0599...
# Analisando o processo 0005542-09.2020.8.26.0451...
# Analisando o processo 1501992-65.2023.8.26.0599...
# Analisando o processo 1501305-88.2023.8.26.0599...
# Analisando o processo 1501564-83.2023.8.26.0599...
# Analisando o processo 1502021-18.2023.8.26.0599...
# Analisando o processo 1500799-15.2023.8.26.0599...
# Analisando o processo 1500335-88.2023.8.26.0599...
# Analisando o processo 1500533-96.2021.8.26.0599...
# Analisando o processo 1501935-81.2022.8.26.0599...
# Analisando o processo 1501289-71.2022.8.26.0599...
# Analisando o processo 1515774-74.2018.8.26.0451...
# Analisando o processo 0001423-51.2017.8.26.0599...
# Analisando o processo 0012353-34.2010.8.26.0451...
# Analisando o processo 1500141-81.2022.8.26.0451...
# Analisando o processo 1500162-98.2022.8.26.0599...
# Analisando o processo 1501219-88.2021.8.26.0599...
# Analisando o processo 1501275-53.2023.8.26.0599...
# Analisando o processo 1509474-28.2020.8.26.0451...
# Analisando o processo 0008376-14.2022.8.26.0451...
# Analisando o processo 1500124-52.2023.8.26.0599...
# Analisando o processo 1500257-31.2022.8.26.0599...
# Analisando o processo 1501784-81.2023.8.26.0599...
# Analisando o processo 1500178-18.2023.8.26.0599...
# Analisando o processo 1500332-36.2023.8.26.0599...
# Analisando o processo 1500983-05.2022.8.26.0599...
# Analisando o processo 1500473-55.2023.8.26.0599...
# Analisando o processo 1500434-58.2023.8.26.0599...
# Analisando o processo 1501004-73.2025.8.26.0599...
# Analisando o processo 1500683-38.2025.8.26.0599...
# Analisando o processo 1501698-13.2023.8.26.0599...
# Analisando o processo 1500551-49.2023.8.26.0599...
# Analisando o processo 1500413-87.2020.8.26.0599...
# Analisando o processo 1501040-23.2022.8.26.0599...
# Analisando o processo 1500965-81.2022.8.26.0599...
# Analisando o processo 1500009-31.2023.8.26.0599...
# Analisando o processo 1500255-27.2023.8.26.0599...
# Analisando o processo 1501615-31.2022.8.26.0599...
# Analisando o processo 1500678-21.2022.8.26.0599...
# Analisando o processo 1501729-67.2022.8.26.0599...
# Analisando o processo 1501200-48.2022.8.26.0599...
# Analisando o processo 1501867-34.2022.8.26.0599...
# Analisando o processo 1501413-88.2021.8.26.0599...
# Analisando o processo 1501853-50.2022.8.26.0599...
# Analisando o processo 1501127-76.2022.8.26.0599...
# Analisando o processo 1501608-39.2022.8.26.0599...
# Analisando o processo 1501489-78.2022.8.26.0599...
# Analisando o processo 1500780-43.2022.8.26.0599...
# Analisando o processo 1500878-28.2022.8.26.0599...
# Analisando o processo 1501681-11.2022.8.26.0599...
# Analisando o processo 1501515-76.2022.8.26.0599...
# Analisando o processo 1500321-41.2022.8.26.0599...
# Analisando o processo 1500256-12.2023.8.26.0599...
# Analisando o processo 1500136-03.2022.8.26.0599...
# Analisando o processo 1501896-84.2022.8.26.0599...
# Analisando o processo 1500440-65.2023.8.26.0599...
# Analisando o processo 1500064-79.2023.8.26.0599...
# Analisando o processo 1500193-84.2023.8.26.0599...
# Analisando o processo 1500806-41.2022.8.26.0599...
# Analisando o processo 0001002-61.2017.8.26.0599...
# Analisando o processo 1501476-16.2021.8.26.0599...
# Analisando o processo 1500897-34.2022.8.26.0599...
# Analisando o processo 1500694-72.2022.8.26.0599...
# Analisando o processo 1500317-67.2023.8.26.0599...
# Analisando o processo 1501306-44.2021.8.26.0599...
# Analisando o processo 1500932-23.2024.8.26.0599...
# Analisando o processo 0007635-71.2022.8.26.0451...
# Analisando o processo 1501510-88.2021.8.26.0599...
# Analisando o processo 1501321-76.2022.8.26.0599...
# Analisando o processo 1501950-50.2022.8.26.0599...
# Analisando o processo 1501052-71.2021.8.26.0599...
# Analisando o processo 1500928-54.2022.8.26.0599...
# Analisando o processo 1502022-71.2021.8.26.0599...
# Analisando o processo 1500475-30.2020.8.26.0599...
# Analisando o processo 1500730-17.2022.8.26.0599...
# Analisando o processo 1500831-54.2022.8.26.0599...
# Analisando o processo 1500661-82.2022.8.26.0599...
# Analisando o processo 1500611-56.2022.8.26.0599...
# Analisando o processo 1500726-77.2022.8.26.0599...
# Analisando o processo 0009162-29.2020.8.26.0451...
# Analisando o processo 0006299-32.2022.8.26.0451...
# Analisando o processo 1500849-75.2022.8.26.0599...
# Analisando o processo 1500740-61.2022.8.26.0599...
# Analisando o processo 1500787-35.2022.8.26.0599...
# Analisando o processo 1500636-69.2022.8.26.0599...
# Analisando o processo 1501513-09.2022.8.26.0599...
# Analisando o processo 1500060-13.2021.8.26.0599...
# Analisando o processo 0007389-46.2020.8.26.0451...
# Analisando o processo 1500487-73.2022.8.26.0599...
# Analisando o processo 1501070-58.2022.8.26.0599...
# Analisando o processo 1500307-57.2022.8.26.0599...
# Analisando o processo 1501187-49.2022.8.26.0599...
# Analisando o processo 0007433-65.2020.8.26.0451...
# Analisando o processo 1500949-30.2022.8.26.0599...
# Analisando o processo 1501153-74.2022.8.26.0599...
# Analisando o processo 1501363-28.2022.8.26.0599...
# Analisando o processo 1501207-40.2022.8.26.0599...
# Analisando o processo 1501357-21.2022.8.26.0599...
# Analisando o processo 1500608-04.2022.8.26.0599...
# Analisando o processo 1501160-66.2022.8.26.0599...
# Analisando o processo 1501808-80.2021.8.26.0599...
# Analisando o processo 1500979-60.2025.8.26.0599...
# Analisando o processo 1500089-29.2022.8.26.0599...
# Analisando o processo 1500384-66.2022.8.26.0599...
# Analisando o processo 1500413-19.2022.8.26.0599...
# Analisando o processo 1500284-14.2022.8.26.0599...
# Analisando o processo 1500200-13.2022.8.26.0599...
# Analisando o processo 1500609-86.2022.8.26.0599...
# Analisando o processo 1501535-04.2021.8.26.0599...
# Analisando o processo 1500712-30.2021.8.26.0599...
# Analisando o processo 1501415-58.2021.8.26.0599...
# Analisando o processo 1502005-35.2021.8.26.0599...
# Analisando o processo 1500792-57.2022.8.26.0599...
# Analisando o processo 1500043-40.2022.8.26.0599...
# Analisando o processo 1500862-74.2022.8.26.0599...
# Analisando o processo 1501337-35.2019.8.26.0599...
# Analisando o processo 1501259-07.2020.8.26.0599...
# Analisando o processo 1500805-56.2022.8.26.0599...
# Analisando o processo 1501839-03.2021.8.26.0599...
# Analisando o processo 1500653-42.2021.8.26.0599...
# Analisando o processo 1500501-57.2022.8.26.0599...
# Analisando o processo 1500566-52.2022.8.26.0599...
# Analisando o processo 1500422-78.2022.8.26.0599...
# Analisando o processo 1500477-29.2022.8.26.0599...
# Analisando o processo 1500778-44.2020.8.26.0599...
# Analisando o processo 1500419-26.2022.8.26.0599...
# Analisando o processo 1500780-48.2019.8.26.0599...
# Analisando o processo 1500248-69.2022.8.26.0599...
# Analisando o processo 1501578-38.2021.8.26.0599...
# Analisando o processo 1501343-71.2021.8.26.0599...
# Analisando o processo 1500524-03.2022.8.26.0599...
# Analisando o processo 1500599-42.2022.8.26.0599...
# Analisando o processo 1500178-52.2022.8.26.0599...
# Analisando o processo 1500011-69.2021.8.26.0599...
# Analisando o processo 1500561-30.2022.8.26.0599...
# Analisando o processo 1500549-16.2022.8.26.0599...
# Analisando o processo 1501621-72.2021.8.26.0599...
# Analisando o processo 1500420-11.2022.8.26.0599...
# Analisando o processo 1500377-74.2022.8.26.0599...
# Analisando o processo 1500334-40.2022.8.26.0599...
# Analisando o processo 1500323-45.2021.8.26.0599...
# Analisando o processo 1501518-65.2021.8.26.0599...
# Analisando o processo 1502020-04.2021.8.26.0599...
# Analisando o processo 1501648-55.2021.8.26.0599...
# Analisando o processo 1501078-69.2021.8.26.0599...
# Analisando o processo 1501173-02.2021.8.26.0599...
# Analisando o processo 1501475-31.2021.8.26.0599...
# Analisando o processo 1500018-27.2022.8.26.0599...
# Analisando o processo 1500990-31.2021.8.26.0599...
# Analisando o processo 0000631-97.2017.8.26.0599...
# Analisando o processo 0007205-08.2011.8.26.0451...
# Analisando o processo 1501494-37.2021.8.26.0599...
# Analisando o processo 1500093-66.2022.8.26.0599...
# Analisando o processo 1501922-19.2021.8.26.0599...
# Analisando o processo 1500858-32.2025.8.26.0599...
# Analisando o processo 1500625-35.2025.8.26.0599...
# Analisando o processo 1501607-88.2021.8.26.0599...
# Analisando o processo 1501290-90.2021.8.26.0599...
# Analisando o processo 1501469-58.2020.8.26.0599...
# Analisando o processo 1500293-78.2019.8.26.0599...
# Analisando o processo 1500091-96.2022.8.26.0599...
# Analisando o processo 0001803-96.2018.8.26.0451...
# Analisando o processo 1500212-27.2022.8.26.0599...
# Analisando o processo 1501046-64.2021.8.26.0599...
# Analisando o processo 1500573-44.2022.8.26.0599...
# Analisando o processo 1501879-82.2021.8.26.0599...
# Analisando o processo 1501040-57.2021.8.26.0599...
# Analisando o processo 1500803-23.2021.8.26.0599...
# Analisando o processo 1501896-21.2021.8.26.0599...
# Analisando o processo 1500589-32.2021.8.26.0599...
# Analisando o processo 1500552-39.2020.8.26.0599...
# Analisando o processo 1500171-60.2022.8.26.0599...
# Analisando o processo 0000386-52.2018.8.26.0599...
# Analisando o processo 1501570-61.2021.8.26.0599...
# Analisando o processo 1502929-05.2021.8.26.0451...
# Analisando o processo 1500264-23.2022.8.26.0599...
# Analisando o processo 1500078-97.2022.8.26.0599...
# Analisando o processo 1501818-27.2021.8.26.0599...
# Analisando o processo 1501315-74.2019.8.26.0599...
# Analisando o processo 1500893-31.2021.8.26.0599...
# Analisando o processo 1501421-36.2019.8.26.0599...
# Analisando o processo 1501220-73.2021.8.26.0599...
# Analisando o processo 1501424-54.2020.8.26.0599...
# Analisando o processo 1501170-06.2021.8.26.0451...
# Analisando o processo 1501425-05.2021.8.26.0599...
# Analisando o processo 1500404-91.2021.8.26.0599...
# Analisando o processo 1500839-65.2021.8.26.0599...
# Analisando o processo 1501725-64.2021.8.26.0599...
# Analisando o processo 1500766-93.2021.8.26.0599...
# Analisando o processo 1501750-77.2021.8.26.0599...
# Analisando o processo 1501814-87.2021.8.26.0599...
# Analisando o processo 1501435-49.2021.8.26.0599...
# Analisando o processo 1501313-36.2021.8.26.0599...
# Analisando o processo 1500573-15.2020.8.26.0599...
# Analisando o processo 0008158-59.2017.8.26.0451...
# Analisando o processo 1500465-49.2021.8.26.0599...
# Analisando o processo 1501469-24.2021.8.26.0599...
# Analisando o processo 0020899-39.2014.8.26.0451...
# Analisando o processo 1501539-41.2021.8.26.0599...
# Analisando o processo 1506414-81.2019.8.26.0451...
# Analisando o processo 1505598-02.2019.8.26.0451...
# Analisando o processo 0006205-55.2020.8.26.0451...
# Analisando o processo 1501528-12.2021.8.26.0599...
# Analisando o processo 1501289-08.2021.8.26.0599...
# Analisando o processo 1501683-15.2021.8.26.0599...
# Analisando o processo 1501514-28.2021.8.26.0599...
# Analisando o processo 1500910-67.2021.8.26.0599...
# Analisando o processo 1501463-17.2021.8.26.0599...
# Analisando o processo 1501664-09.2021.8.26.0599...
# Analisando o processo 1501402-59.2021.8.26.0599...
# Analisando o processo 1500505-31.2021.8.26.0599...
# Analisando o processo 0013099-86.2016.8.26.0451...
# Analisando o processo 1501330-09.2020.8.26.0599...
# Analisando o processo 1500769-48.2021.8.26.0599...
# Analisando o processo 1500900-23.2021.8.26.0599...
# Analisando o processo 1500935-80.2021.8.26.0599...
# Analisando o processo 1500220-38.2021.8.26.0599...
# Analisando o processo 0003715-02.2016.8.26.0451...
# Analisando o processo 1500270-98.2020.8.26.0599...
# Analisando o processo 1500408-31.2021.8.26.0599...
# Analisando o processo 1500659-83.2020.8.26.0599...
# Analisando o processo 1501522-05.2021.8.26.0599...
# Analisando o processo 1501438-04.2021.8.26.0599...
# Analisando o processo 1501133-20.2021.8.26.0599...
# Analisando o processo 1500754-79.2021.8.26.0599...
# Analisando o processo 1500235-07.2021.8.26.0599...
# Analisando o processo 1501257-03.2021.8.26.0599...
# Analisando o processo 1501488-30.2021.8.26.0599...
# Analisando o processo 1501329-87.2021.8.26.0599...
# Analisando o processo 1501424-20.2021.8.26.0599...
# Analisando o processo 1501034-50.2021.8.26.0599...
# Analisando o processo 1501163-55.2021.8.26.0599...
# Analisando o processo 1500744-69.2020.8.26.0599...
# Analisando o processo 1545988-77.2020.8.26.0451...
# Analisando o processo 1500978-17.2021.8.26.0599...
# Analisando o processo 1501225-95.2021.8.26.0599...
# Analisando o processo 1501289-42.2020.8.26.0599...
# Analisando o processo 1501202-52.2021.8.26.0599...
# Analisando o processo 1500516-60.2021.8.26.0599...
# Analisando o processo 1501277-91.2021.8.26.0599...
# Analisando o processo 1500645-65.2021.8.26.0599...
# Analisando o processo 0010450-12.2020.8.26.0451...
# Analisando o processo 1500892-46.2021.8.26.0599...
# Analisando o processo 1500787-69.2021.8.26.0599...
# Analisando o processo 1500575-48.2021.8.26.0599...
# Analisando o processo 1501206-26.2020.8.26.0599...
# Analisando o processo 1501151-41.2021.8.26.0599...
# Analisando o processo 1500964-33.2021.8.26.0599...
# Analisando o processo 1501089-69.2019.8.26.0599...
# Analisando o processo 1500918-44.2021.8.26.0599...
# Analisando o processo 1501208-59.2021.8.26.0599...
# Analisando o processo 1501108-07.2021.8.26.0599...
# Analisando o processo 1500489-77.2021.8.26.0599...
# Analisando o processo 1500938-35.2021.8.26.0599...
# Analisando o processo 1501033-65.2021.8.26.0599...
# Analisando o processo 1501145-34.2021.8.26.0599...
# Analisando o processo 1500819-74.2021.8.26.0599...
# Analisando o processo 1500398-21.2020.8.26.0599...
# Analisando o processo 1500144-48.2020.8.26.0599...
# Analisando o processo 1500141-59.2021.8.26.0599...
# Analisando o processo 1500966-03.2021.8.26.0599...
# Analisando o processo 1500996-38.2021.8.26.0599...
# Analisando o processo 1500943-57.2021.8.26.0599...
# Analisando o processo 1500660-34.2021.8.26.0599...
# Analisando o processo 1500644-80.2021.8.26.0599...
# Analisando o processo 0000027-71.2012.8.26.0451...
# Analisando o processo 1500958-84.2025.8.26.0599...
# Analisando o processo 1501203-95.2025.8.26.0599...
# Analisando o processo 1500714-97.2021.8.26.0599...
# Analisando o processo 1500477-63.2021.8.26.0599...
# Analisando o processo 1500570-26.2021.8.26.0599...
# Analisando o processo 1500506-16.2021.8.26.0599...
# Analisando o processo 1500432-64.2018.8.26.0599...
# Analisando o processo 1541203-72.2020.8.26.0451...
# Analisando o processo 1500559-94.2021.8.26.0599...
# Analisando o processo 1500999-90.2021.8.26.0599...
# Analisando o processo 1501362-14.2020.8.26.0599...
# Analisando o processo 1500076-98.2020.8.26.0599...
# Analisando o processo 1500859-90.2020.8.26.0599...
# Analisando o processo 1500782-47.2021.8.26.0599...
# Analisando o processo 1500701-98.2021.8.26.0599...
# Analisando o processo 1500745-54.2020.8.26.0599...
# Analisando o processo 1500632-66.2021.8.26.0599...
# Analisando o processo 1500694-77.2019.8.26.0599...
# Analisando o processo 1500268-94.2021.8.26.0599...
# Analisando o processo 1500558-12.2021.8.26.0599...
# Analisando o processo 1500692-39.2021.8.26.0599...
# Analisando o processo 1500295-14.2020.8.26.0599...
# Analisando o processo 1500775-55.2021.8.26.0599...
# Analisando o processo 1500260-20.2021.8.26.0599...
# Analisando o processo 1501102-68.2019.8.26.0599...
# Analisando o processo 0000202-91.2021.8.26.0599...
# Analisando o processo 1500172-84.2018.8.26.0599...
# Analisando o processo 1501151-75.2020.8.26.0599...
# Analisando o processo 1501309-33.2020.8.26.0599...
# Analisando o processo 1501279-95.2020.8.26.0599...
# Analisando o processo 0000050-43.2021.8.26.0599...
# Analisando o processo 1500093-03.2021.8.26.0599...
# Analisando o processo 1500122-53.2021.8.26.0599...
# Analisando o processo 1501319-77.2020.8.26.0599...
# Analisando o processo 1501586-49.2020.8.26.0599...
# Analisando o processo 1501663-92.2019.8.26.0599...
# Analisando o processo 0000208-98.2021.8.26.0599...
# Analisando o processo 1501575-20.2020.8.26.0599...
# Analisando o processo 0000214-13.2018.8.26.0599...
# Analisando o processo 1500436-96.2021.8.26.0599...
# Analisando o processo 1501164-74.2020.8.26.0599...
# Analisando o processo 1500315-68.2021.8.26.0599...
# Analisando o processo 1500148-51.2021.8.26.0599...
# Analisando o processo 1501484-27.2020.8.26.0599...
# Analisando o processo 1501708-96.2019.8.26.0599...
# Analisando o processo 1500369-68.2020.8.26.0599...
# Analisando o processo 1500986-28.2020.8.26.0599...
# Analisando o processo 1501390-79.2020.8.26.0599...
# Analisando o processo 1501324-02.2020.8.26.0599...
# Analisando o processo 1500199-62.2021.8.26.0599...
# Analisando o processo 1501653-14.2020.8.26.0599...
# Analisando o processo 1500039-37.2021.8.26.0599...
# Analisando o processo 1500108-69.2021.8.26.0599...
# Analisando o processo 1500250-73.2021.8.26.0599...
# Analisando o processo 1501574-69.2019.8.26.0599...
# Analisando o processo 1501376-95.2020.8.26.0599...
# Analisando o processo 1500124-23.2021.8.26.0599...
# Analisando o processo 1500396-17.2021.8.26.0599...
# Analisando o processo 1500208-24.2021.8.26.0599...
# Analisando o processo 1500125-08.2021.8.26.0599...
# Analisando o processo 0000909-98.2017.8.26.0599...
# Analisando o processo 1500297-47.2021.8.26.0599...
# Analisando o processo 1501120-55.2020.8.26.0599...
# Analisando o processo 1501462-66.2020.8.26.0599...
# Analisando o processo 1501565-73.2020.8.26.0599...
# Analisando o processo 1500782-18.2019.8.26.0599...
# Analisando o processo 1500256-80.2021.8.26.0599...
# Analisando o processo 1501304-11.2020.8.26.0599...
# Analisando o processo 1500022-98.2021.8.26.0599...
# Analisando o processo 1501568-28.2020.8.26.0599...
# Analisando o processo 1501398-56.2020.8.26.0599...
# Analisando o processo 1500371-38.2020.8.26.0599...
# Analisando o processo 1501539-75.2020.8.26.0599...
# Analisando o processo 1501383-87.2020.8.26.0599...
# Analisando o processo 1501687-23.2019.8.26.0599...
# Analisando o processo 1501440-08.2020.8.26.0599...
# Analisando o processo 1500050-66.2021.8.26.0599...
# Analisando o processo 1501251-30.2020.8.26.0599...
# Analisando o processo 1501349-15.2020.8.26.0599...
# Analisando o processo 1500065-35.2021.8.26.0599...
# Analisando o processo 1501716-73.2019.8.26.0599...
# Analisando o processo 1500090-48.2021.8.26.0599...
# Analisando o processo 1501413-25.2020.8.26.0599...
# Analisando o processo 0006237-60.2020.8.26.0451...
# Analisando o processo 1500857-23.2020.8.26.0599...
# Analisando o processo 1500763-75.2020.8.26.0599...
# Analisando o processo 1500769-82.2020.8.26.0599...
# Analisando o processo 1500795-80.2020.8.26.0599...
# Analisando o processo 1501128-32.2020.8.26.0599...
# Analisando o processo 1501380-35.2020.8.26.0599...
# Analisando o processo 1501149-08.2020.8.26.0599...
# Analisando o processo 1500760-23.2020.8.26.0599...
# Analisando o processo 0016537-18.2019.8.26.0451...
# Analisando o processo 1501228-84.2020.8.26.0599...
# Analisando o processo 0000649-84.2018.8.26.0599...
# Analisando o processo 1501018-33.2020.8.26.0599...
# Analisando o processo 1500595-73.2020.8.26.0599...
# Analisando o processo 1501234-91.2020.8.26.0599...
# Analisando o processo 1500916-11.2020.8.26.0599...
# Analisando o processo 1500345-64.2025.8.26.0599...
# Analisando o processo 1500100-53.2025.8.26.0599...
# Analisando o processo 1500866-09.2025.8.26.0599...
# Analisando o processo 1501086-41.2024.8.26.0599...
# Analisando o processo 1500774-31.2025.8.26.0599...
# Analisando o processo 1501240-35.2019.8.26.0599...
# Analisando o processo 1501042-61.2020.8.26.0599...
# Analisando o processo 1501223-62.2020.8.26.0599...
# Analisando o processo 1500821-78.2020.8.26.0599...
# Analisando o processo 1501776-46.2019.8.26.0599...
# Analisando o processo 0000055-02.2020.8.26.0599...
# Analisando o processo 0000600-77.2017.8.26.0599...
# Analisando o processo 1500305-58.2020.8.26.0599...
# Analisando o processo 1501557-33.2019.8.26.0599...
# Analisando o processo 1501726-20.2019.8.26.0599...
# Analisando o processo 1501588-53.2019.8.26.0599...
# Analisando o processo 1501218-40.2020.8.26.0599...
# Analisando o processo 1501250-45.2020.8.26.0599...
# Analisando o processo 1500914-41.2020.8.26.0599...
# Analisando o processo 0016522-49.2019.8.26.0451...
# Analisando o processo 0000081-97.2020.8.26.0599...
# Analisando o processo 0006221-09.2020.8.26.0451...
# Analisando o processo 1500737-14.2019.8.26.0599...
# Analisando o processo 1501413-59.2019.8.26.0599...
# Analisando o processo 1500683-14.2020.8.26.0599...
# Analisando o processo 1500694-43.2020.8.26.0599...
# Analisando o processo 1500873-74.2020.8.26.0599...
# Analisando o processo 1500867-67.2020.8.26.0599...
# Analisando o processo 1501124-92.2020.8.26.0599...
# Analisando o processo 1500360-09.2020.8.26.0599...
# Analisando o processo 1500631-18.2020.8.26.0599...
# Analisando o processo 1500796-65.2020.8.26.0599...
# Analisando o processo 1501201-04.2020.8.26.0599...
# Analisando o processo 1501301-90.2019.8.26.0599...
# Analisando o processo 1500679-74.2020.8.26.0599...
# Analisando o processo 1500442-40.2020.8.26.0599...
# Analisando o processo 1500486-59.2020.8.26.0599...
# Analisando o processo 1500854-68.2020.8.26.0599...
# Analisando o processo 1500991-50.2020.8.26.0599...
# Analisando o processo 1500065-69.2020.8.26.0599...
# Analisando o processo 1501061-67.2020.8.26.0599...
# Analisando o processo 1501005-34.2020.8.26.0599...
# Analisando o processo 1501195-94.2020.8.26.0599...
# Analisando o processo 1500719-56.2020.8.26.0599...
# Analisando o processo 1500132-34.2020.8.26.0599...
# Analisando o processo 1500179-08.2020.8.26.0599...
# Analisando o processo 1500974-14.2020.8.26.0599...
# Analisando o processo 1500193-89.2020.8.26.0599...
# Analisando o processo 1501759-10.2019.8.26.0599...
# Analisando o processo 1500948-16.2020.8.26.0599...
# Analisando o processo 0013117-39.2018.8.26.0451...
# Analisando o processo 1500632-03.2020.8.26.0599...
# Analisando o processo 1508615-46.2019.8.26.0451...
# Analisando o processo 0002184-46.2014.8.26.0451...
# Analisando o processo 1500546-32.2020.8.26.0599...
# Analisando o processo 1500805-27.2020.8.26.0599...
# Analisando o processo 0000574-16.2016.8.26.0599...
# Analisando o processo 1500712-64.2020.8.26.0599...
# Analisando o processo 1500037-04.2020.8.26.0599...
# Analisando o processo 1500593-06.2020.8.26.0599...
# Analisando o processo 1501882-08.2019.8.26.0599...
# Analisando o processo 1500780-14.2020.8.26.0599...
# Analisando o processo 1500044-93.2020.8.26.0599...
# Analisando o processo 1501016-63.2020.8.26.0599...
# Analisando o processo 1500762-90.2020.8.26.0599...
# Analisando o processo 1500582-74.2020.8.26.0599...
# Analisando o processo 1500715-19.2020.8.26.0599...
# Analisando o processo 1500151-40.2020.8.26.0599...
# Analisando o processo 1500934-32.2020.8.26.0599...
# Analisando o processo 1542430-97.2020.8.26.0451...
# Analisando o processo 1500923-03.2020.8.26.0599...
# Analisando o processo 1500716-04.2020.8.26.0599...
# Analisando o processo 1500890-13.2020.8.26.0599...
# Analisando o processo 1500652-91.2020.8.26.0599...
# Analisando o processo 1500827-85.2020.8.26.0599...
# Analisando o processo 1500701-35.2020.8.26.0599...
# Analisando o processo 1500685-81.2020.8.26.0599...
# Analisando o processo 1500687-75.2025.8.26.0599...
# Analisando o processo 1501780-15.2021.8.26.0599...
# Analisando o processo 1500510-24.2019.8.26.0599...
# Analisando o processo 0008210-21.2018.8.26.0451...
# Analisando o processo 1501719-28.2019.8.26.0599...
# Analisando o processo 1501343-42.2019.8.26.0599...
# Analisando o processo 1501438-72.2019.8.26.0599...
# Analisando o processo 1500614-79.2020.8.26.0599...
# Analisando o processo 1500695-28.2020.8.26.0599...
# Analisando o processo 1500628-63.2020.8.26.0599...
# Analisando o processo 1500104-66.2020.8.26.0599...
# Analisando o processo 1500071-76.2020.8.26.0599...
# Analisando o processo 1500771-52.2020.8.26.0599...
# Analisando o processo 1500602-65.2020.8.26.0599...
# Analisando o processo 1500169-61.2020.8.26.0599...
# Analisando o processo 1500416-42.2020.8.26.0599...
# Analisando o processo 1500417-27.2020.8.26.0599...
# Analisando o processo 1500308-13.2020.8.26.0599...
# Analisando o processo 1500328-04.2020.8.26.0599...
# Analisando o processo 1500731-70.2020.8.26.0599...
# Analisando o processo 1501709-81.2019.8.26.0599...
# Analisando o processo 1500620-86.2020.8.26.0599...
# Analisando o processo 1501598-97.2019.8.26.0599...
# Analisando o processo 1500556-76.2020.8.26.0599...
# Analisando o processo 1500123-72.2020.8.26.0599...
# Analisando o processo 1500313-35.2020.8.26.0599...
# Analisando o processo 1500237-11.2020.8.26.0599...
# Analisando o processo 1500182-60.2020.8.26.0599...
# Analisando o processo 1500676-22.2020.8.26.0599...
# Analisando o processo 1500175-68.2020.8.26.0599...
# Analisando o processo 1500639-92.2020.8.26.0599...
# Analisando o processo 1500629-48.2020.8.26.0599...
# Analisando o processo 1500572-30.2020.8.26.0599...
# Analisando o processo 1500621-71.2020.8.26.0599...
# Analisando o processo 1500142-78.2020.8.26.0599...
# Analisando o processo 1500462-31.2020.8.26.0599...
# Analisando o processo 1500080-38.2020.8.26.0599...
# Analisando o processo 1500577-52.2020.8.26.0599...
# Analisando o processo 1500544-62.2020.8.26.0599...
# Analisando o processo 1500533-33.2020.8.26.0599...
# Analisando o processo 1501841-41.2019.8.26.0599...
# Analisando o processo 1500831-59.2019.8.26.0599...
# Analisando o processo 0000344-93.2017.8.26.0451...
# Analisando o processo 1542239-23.2018.8.26.0451...
# Analisando o processo 1500867-04.2019.8.26.0599...
# Analisando o processo 1501845-78.2019.8.26.0599...
# Analisando o processo 1500262-24.2020.8.26.0599...
# Analisando o processo 1500288-22.2020.8.26.0599...
# Analisando o processo 1501692-45.2019.8.26.0599...
# Analisando o processo 1500195-59.2020.8.26.0599...
# Analisando o processo 0003483-19.2018.8.26.0451...
# Analisando o processo 1501766-02.2019.8.26.0599...
# Analisando o processo 1500560-50.2019.8.26.0599...
# Analisando o processo 1500790-92.2019.8.26.0599...
# Analisando o processo 1500231-72.2018.8.26.0599...
# Analisando o processo 1501006-53.2019.8.26.0599...
# Analisando o processo 1500883-55.2019.8.26.0599...
# Analisando o processo 0016640-30.2016.8.26.0451...
# Analisando o processo 1500607-24.2019.8.26.0599...
# Analisando o processo 0000469-68.2018.8.26.0599...
# Analisando o processo 1500362-13.2019.8.26.0599...
# Analisando o processo 1501521-78.2025.8.26.0599...
# Analisando o processo 1501263-68.2025.8.26.0599...
# Analisando o processo 1501498-35.2025.8.26.0599...
# Analisando o processo 1501416-04.2025.8.26.0599...
# Analisando o processo 1500521-43.2025.8.26.0599...
# Analisando o processo 1500115-22.2025.8.26.0599...
# Analisando o processo 1501975-92.2024.8.26.0599...
# Analisando o processo 0001539-57.2017.8.26.0599...
# Analisando o processo 0009460-60.2016.8.26.0451...
# Analisando o processo 1500708-95.2018.8.26.0599...
# Analisando o processo 1500166-43.2019.8.26.0599...
# Analisando o processo 0000619-49.2018.8.26.0599...
# Analisando o processo 1500757-39.2018.8.26.0599...
# Analisando o processo 1500977-03.2019.8.26.0599...
# Analisando o processo 1500141-30.2019.8.26.0599...
# Analisando o processo 1500544-33.2018.8.26.0599...
# Analisando o processo 1500426-57.2018.8.26.0599...
# Analisando o processo 1501070-63.2019.8.26.0599...
# Analisando o processo 1500052-07.2019.8.26.0599...
# Analisando o processo 0003418-44.2006.8.26.0451...
# Analisando o processo 1501360-78.2019.8.26.0599...
# Analisando o processo 1500469-61.2019.8.26.0630...
# Analisando o processo 1500138-75.2019.8.26.0599...
# Analisando o processo 1500116-17.2019.8.26.0599...
# Analisando o processo 0000296-78.2017.8.26.0599...
# Analisando o processo 0002545-92.2016.8.26.0451...
# Analisando o processo 1500685-18.2019.8.26.0599...
# Analisando o processo 1500695-96.2018.8.26.0599...
# Analisando o processo 1500489-48.2019.8.26.0599...
# Analisando o processo 1500547-85.2018.8.26.0599...
# Analisando o processo 0000604-80.2018.8.26.0599...
# Analisando o processo 1500470-76.2018.8.26.0599...
# Analisando o processo 1500213-17.2019.8.26.0599...
# Analisando o processo 0001819-50.2018.8.26.0451...
# Analisando o processo 1500583-30.2018.8.26.0599...
# Analisando o processo 0001525-73.2017.8.26.0599...
# Analisando o processo 1500462-65.2019.8.26.0599...
# Analisando o processo 1500732-26.2018.8.26.0599...
# Analisando o processo 0008579-15.2018.8.26.0451...
# Analisando o processo 0006336-69.2016.8.26.0451...
# Analisando o processo 1500656-65.2019.8.26.0599...
# Analisando o processo 0001639-12.2017.8.26.0599...
# Analisando o processo 1500150-26.2018.8.26.0599...
# Analisando o processo 1532287-78.2022.8.26.0451...
# Analisando o processo 1500684-33.2019.8.26.0599...
# Analisando o processo 1500672-19.2019.8.26.0599...
# Analisando o processo 1500192-41.2019.8.26.0599...
# Analisando o processo 1500103-52.2018.8.26.0599...
# Analisando o processo 1500037-72.2018.8.26.0599...
# Analisando o processo 1500480-23.2018.8.26.0599...
# Analisando o processo 1500515-80.2018.8.26.0599...
# Analisando o processo 0000082-53.2018.8.26.0599...
# Analisando o processo 1500173-35.2019.8.26.0599...
# Analisando o processo 0009713-82.2015.8.26.0451...
# Analisando o processo 0000341-48.2018.8.26.0599...
# Analisando o processo 0001507-52.2017.8.26.0599...
# Analisando o processo 0002939-36.2015.8.26.0451...
# Analisando o processo 0000405-29.2016.8.26.0599...
# Analisando o processo 0014351-27.2016.8.26.0451...
# Analisando o processo 0000980-03.2017.8.26.0599...
# Analisando o processo 0000406-43.2018.8.26.0599...
# Analisando o processo 0003979-68.2006.8.26.0451...
# Analisando o processo 1500721-94.2018.8.26.0599...
# Analisando o processo 1500271-54.2018.8.26.0599...
# Analisando o processo 0001494-17.2014.8.26.0451...
# Analisando o processo 1500045-49.2018.8.26.0599...
# Analisando o processo 0001360-26.2017.8.26.0599...
# Analisando o processo 0000164-84.2018.8.26.0599...
# Analisando o processo 1500116-51.2018.8.26.0599...
# Analisando o processo 0006836-72.2015.8.26.0451...
# Analisando o processo 1500134-72.2018.8.26.0599...
# Analisando o processo 1500536-12.2025.8.26.0599...
# Analisando o processo 0014025-96.2018.8.26.0451...
# Analisando o processo 1500143-34.2018.8.26.0599...
# Analisando o processo 0000172-61.2018.8.26.0599...
# Analisando o processo 0001404-45.2017.8.26.0599...
# Analisando o processo 0000686-48.2017.8.26.0599...
# Analisando o processo 0001122-07.2017.8.26.0599...
# Analisando o processo 0009821-09.2018.8.26.0451...
# Analisando o processo 0000327-64.2018.8.26.0599...
# Analisando o processo 0000335-75.2017.8.26.0599...
# Analisando o processo 0000621-19.2018.8.26.0599...
# Analisando o processo 0000288-67.2018.8.26.0599...
# Analisando o processo 0019004-43.2014.8.26.0451...
# Analisando o processo 0000439-33.2018.8.26.0599...
# Analisando o processo 0028148-22.2006.8.26.0451...
# Analisando o processo 0013302-19.2014.8.26.0451...
# Analisando o processo 0001146-35.2017.8.26.0599...
# Analisando o processo 0000012-34.2014.8.26.0451...
# Analisando o processo 0000166-59.2015.8.26.0599...
# Analisando o processo 0001315-22.2017.8.26.0599...
# Analisando o processo 0000430-71.2018.8.26.0599...
# Analisando o processo 0001187-02.2017.8.26.0599...
# Analisando o processo 0016894-03.2016.8.26.0451...
# Analisando o processo 0004979-83.2018.8.26.0451...
# Analisando o processo 0000577-34.2017.8.26.0599...
# Analisando o processo 0000090-30.2018.8.26.0599...
# Analisando o processo 0000213-28.2018.8.26.0599...
# Analisando o processo 0001320-44.2017.8.26.0599...
# Analisando o processo 0005563-05.2008.8.26.0451...
# Analisando o processo 0067589-15.2003.8.26.0451...
# Analisando o processo 0007321-72.2015.8.26.0451...
# Analisando o processo 0000767-94.2017.8.26.0599...
# Analisando o processo 0001089-17.2017.8.26.0599...
# Analisando o processo 0000055-70.2018.8.26.0599...
# Analisando o processo 0000227-46.2017.8.26.0599...
# Analisando o processo 0004254-36.2014.8.26.0451...
# Analisando o processo 0000176-98.2018.8.26.0599...
# Analisando o processo 1500319-66.2025.8.26.0599...
# Analisando o processo 0002065-07.2022.8.26.0451...
# Analisando o processo 0000359-06.2017.8.26.0599...
# Analisando o processo 0000147-82.2017.8.26.0599...
# Analisando o processo 0000207-21.2018.8.26.0599...
# Analisando o processo 0001161-04.2017.8.26.0599...
# Analisando o processo 0000130-12.2018.8.26.0599...
# Analisando o processo 0000080-20.2017.8.26.0599...
# Analisando o processo 0008796-29.2016.8.26.0451...
# Analisando o processo 0003415-40.2016.8.26.0451...
# Analisando o processo 0004251-13.2016.8.26.0451...
# Analisando o processo 0000022-51.2016.8.26.0599...
# Analisando o processo 0008807-58.2016.8.26.0451...
# Analisando o processo 0000031-42.2018.8.26.0599...
# Analisando o processo 0001312-67.2017.8.26.0599...
# Analisando o processo 0000155-25.2018.8.26.0599...
# Analisando o processo 0000865-72.2016.8.26.0451...
# Analisando o processo 0001262-41.2017.8.26.0599...
# Analisando o processo 0001085-77.2017.8.26.0599...
# Analisando o processo 0001479-84.2017.8.26.0599...
# Analisando o processo 0002383-63.2017.8.26.0451...
# Analisando o processo 0000105-96.2018.8.26.0599...
# Analisando o processo 0016071-92.2017.8.26.0451...
# Analisando o processo 0033913-95.2011.8.26.0451...
# Analisando o processo 0000406-77.2017.8.26.0599...
# Analisando o processo 0000397-18.2017.8.26.0599...
# Analisando o processo 0000898-69.2017.8.26.0599...
# Analisando o processo 0002517-90.2017.8.26.0451...
# Analisando o processo 0056081-43.2001.8.26.0451...
# Analisando o processo 0000951-50.2017.8.26.0599...
# Analisando o processo 0000952-35.2017.8.26.0599...
# Analisando o processo 0001166-26.2017.8.26.0599...
# Analisando o processo 0000974-93.2017.8.26.0599...
# Analisando o processo 0000586-93.2017.8.26.0599...
# Analisando o processo 0018020-25.2015.8.26.0451...
# Analisando o processo 0006781-58.2014.8.26.0451...
# Analisando o processo 0001143-80.2017.8.26.0599...
# Analisando o processo 0000918-60.2017.8.26.0599...
# Analisando o processo 0014050-17.2015.8.26.0451...
# Analisando o processo 0008621-69.2015.8.26.0451...
# Analisando o processo 0000277-72.2017.8.26.0599...
# Analisando o processo 0000580-86.2017.8.26.0599...
# Analisando o processo 0000852-80.2017.8.26.0599...
# Analisando o processo 0000865-79.2017.8.26.0599...
# Analisando o processo 0000465-36.2015.8.26.0599...
# Analisando o processo 0073251-57.2003.8.26.0451...
# Analisando o processo 0000569-57.2017.8.26.0599...
# Analisando o processo 0000774-86.2017.8.26.0599...
# Analisando o processo 0000910-83.2017.8.26.0599...
# Analisando o processo 0000620-68.2017.8.26.0599...
# Analisando o processo 0000741-96.2017.8.26.0599...
# Analisando o processo 0000635-37.2017.8.26.0599...
# Analisando o processo 0000554-88.2017.8.26.0599...
# Analisando o processo 0000133-98.2017.8.26.0599...
# Analisando o processo 0000844-06.2017.8.26.0599...
# Analisando o processo 0000024-84.2017.8.26.0599...
# Analisando o processo 0017157-35.2016.8.26.0451...
# Analisando o processo 0012954-64.2015.8.26.0451...
# Analisando o processo 0000725-79.2016.8.26.0599...
# Analisando o processo 0010833-29.2016.8.26.0451...
# Analisando o processo 0040157-11.2009.8.26.0451...
# Analisando o processo 0000337-45.2017.8.26.0599...
# Analisando o processo 0002912-53.2015.8.26.0451...
# Analisando o processo 0001413-97.2016.8.26.0451...
# Analisando o processo 0008395-74.2009.8.26.0451...
# Analisando o processo 0000508-02.2017.8.26.0599...
# Analisando o processo 0000712-05.2017.8.26.0451...
# Analisando o processo 0000408-47.2017.8.26.0599...
# Analisando o processo 0000330-87.2016.8.26.0599...
# Analisando o processo 0006186-88.2016.8.26.0451...
# Analisando o processo 0000228-31.2017.8.26.0599...
# Analisando o processo 0000203-18.2017.8.26.0599...
# Analisando o processo 0000392-93.2017.8.26.0599...
# Analisando o processo 0000213-62.2017.8.26.0599...
# Analisando o processo 0000276-87.2017.8.26.0599...
# Analisando o processo 0000123-54.2017.8.26.0599...
# Analisando o processo 0000305-40.2017.8.26.0599...
# Analisando o processo 0007749-20.2016.8.26.0451...
# Analisando o processo 0014193-06.2015.8.26.0451...
# Analisando o processo 0009800-04.2016.8.26.0451...
# Analisando o processo 0000090-64.2017.8.26.0599...
# Analisando o processo 0000760-39.2016.8.26.0599...
# Analisando o processo 0013730-30.2016.8.26.0451...
# Analisando o processo 0009440-40.2014.8.26.0451...
# Analisando o processo 0008795-44.2016.8.26.0451...
# Analisando o processo 0009866-52.2014.8.26.0451...
# Analisando o processo 0000547-33.2016.8.26.0599...
# Analisando o processo 0000197-11.2017.8.26.0599...
# Analisando o processo 0014813-81.2016.8.26.0451...
# Analisando o processo 0000182-42.2017.8.26.0599...
# Analisando o processo 0000135-68.2017.8.26.0599...
# Analisando o processo 0007576-30.2015.8.26.0451...
# Analisando o processo 0006828-61.2016.8.26.0451...
# Analisando o processo 0000441-71.2016.8.26.0599...
# Analisando o processo 0002827-33.2016.8.26.0451...
# Analisando o processo 0000669-80.2015.8.26.0599...
# Analisando o processo 0028372-81.2011.8.26.0451...
# Analisando o processo 0004912-26.2015.8.26.0451...
# Analisando o processo 0000225-76.2017.8.26.0599...
# Analisando o processo 0003069-89.2016.8.26.0451...
# Analisando o processo 0032523-90.2011.8.26.0451...
# Analisando o processo 3011990-88.2013.8.26.0451...
# Analisando o processo 0014460-41.2016.8.26.0451...
# Analisando o processo 0013236-39.2014.8.26.0451...
# Analisando o processo 0000230-35.2016.8.26.0599...
# Analisando o processo 0016003-79.2016.8.26.0451...
# Analisando o processo 0003967-39.2015.8.26.0451...
# Analisando o processo 0000565-54.2016.8.26.0599...
# Analisando o processo 0000531-79.2016.8.26.0599...
# Analisando o processo 0000143-79.2016.8.26.0599...
# Analisando o processo 0001787-50.2015.8.26.0451...
# Analisando o processo 0017781-21.2015.8.26.0451...
# Analisando o processo 0018000-34.2015.8.26.0451...
# Analisando o processo 1501233-26.2024.8.26.0451...
# Analisando o processo 1500550-30.2024.8.26.0599...
# Analisando o processo 0000259-44.2016.8.26.0451...
# Analisando o processo 0005364-02.2016.8.26.0451...
# Analisando o processo 0004036-37.2016.8.26.0451...
# Analisando o processo 0000146-34.2016.8.26.0599...
# Analisando o processo 0001855-63.2016.8.26.0451...
# Analisando o processo 0014028-22.2016.8.26.0451...
# Analisando o processo 0014349-57.2016.8.26.0451...
# Analisando o processo 0016446-98.2014.8.26.0451...
# Analisando o processo 0012295-21.2016.8.26.0451...
# Analisando o processo 0003547-97.2016.8.26.0451...
# Analisando o processo 0000400-07.2016.8.26.0599...
# Analisando o processo 0002399-85.2015.8.26.0451...
# Analisando o processo 0008243-55.2011.8.26.0451...
# Analisando o processo 3010864-03.2013.8.26.0451...
# Analisando o processo 3015591-05.2013.8.26.0451...
# Analisando o processo 0033593-45.2011.8.26.0451...
# Analisando o processo 0056027-77.2001.8.26.0451...
# Analisando o processo 0006628-88.2015.8.26.0451...
# Analisando o processo 0000324-80.2016.8.26.0599...
# Analisando o processo 0007853-12.2016.8.26.0451...
# Analisando o processo 0010751-95.2016.8.26.0451...
# Analisando o processo 0002689-66.2016.8.26.0451...
# Analisando o processo 0001306-53.2016.8.26.0451...
# Analisando o processo 0000116-96.2016.8.26.0599...
# Analisando o processo 0003667-77.2015.8.26.0451...
# Analisando o processo 0003530-61.2016.8.26.0451...
# Analisando o processo 0014366-30.2015.8.26.0451...
# Analisando o processo 0005701-88.2016.8.26.0451...
# Analisando o processo 0000090-98.2016.8.26.0599...
# Analisando o processo 0013373-89.2012.8.26.0451...
# Analisando o processo 0002618-35.2014.8.26.0451...
# Analisando o processo 0000152-41.2016.8.26.0599...
# Analisando o processo 0000216-51.2016.8.26.0599...
# Analisando o processo 0002870-67.2016.8.26.0451...
# Analisando o processo 0006829-46.2016.8.26.0451...
# Analisando o processo 0000724-31.2015.8.26.0599...
# Analisando o processo 0000257-74.2016.8.26.0451...
# Analisando o processo 0000043-83.2016.8.26.0451...
# Analisando o processo 0001641-72.2016.8.26.0451...
# Analisando o processo 0017785-58.2015.8.26.0451...
# Analisando o processo 0006965-43.2016.8.26.0451...
# Analisando o processo 0005928-78.2016.8.26.0451...
# Analisando o processo 0002962-21.2011.8.26.0451...
# Analisando o processo 1502155-11.2024.8.26.0599...
# Analisando o processo 0000334-68.2025.8.26.0451...
# Analisando o processo 0001930-20.2007.8.26.0451...
# Analisando o processo 3002592-20.2013.8.26.0451...
# Analisando o processo 0009179-75.2014.8.26.0451...
# Analisando o processo 0000279-13.2015.8.26.0599...
# Analisando o processo 0001697-42.2015.8.26.0451...
# Analisando o processo 0012642-25.2014.8.26.0451...
# Analisando o processo 0002062-96.2015.8.26.0451...
# Analisando o processo 0002803-05.2016.8.26.0451...
# Analisando o processo 0013131-28.2015.8.26.0451...
# Analisando o processo 0015037-53.2015.8.26.0451...
# Analisando o processo 0007393-93.2014.8.26.0451...
# Analisando o processo 0003211-93.2016.8.26.0451...
# Analisando o processo 0001110-83.2016.8.26.0451...
# Analisando o processo 0017293-03.2014.8.26.0451...
# Analisando o processo 0002320-09.2015.8.26.0451...
# Analisando o processo 0016760-10.2015.8.26.0451...
# Analisando o processo 0027993-87.2004.8.26.0451...
# Analisando o processo 0014444-63.2011.8.26.0451...
# Analisando o processo 0001638-20.2016.8.26.0451...
# Analisando o processo 0014545-61.2015.8.26.0451...
# Analisando o processo 0021368-85.2014.8.26.0451...
# Analisando o processo 0002633-33.2016.8.26.0451...
# Analisando o processo 0008335-91.2015.8.26.0451...
# Analisando o processo 3009865-50.2013.8.26.0451...
# Analisando o processo 0006696-38.2015.8.26.0451...
# Analisando o processo 0007834-40.2015.8.26.0451...
# Analisando o processo 0015976-33.2015.8.26.0451...
# Analisando o processo 3012276-66.2013.8.26.0451...
# Analisando o processo 0003041-97.2011.8.26.0451...
# Analisando o processo 0000332-91.2015.8.26.0599...
# Analisando o processo 0024405-91.2012.8.26.0451...
# Analisando o processo 3001678-53.2013.8.26.0451...
# Analisando o processo 0000196-94.2015.8.26.0599...
# Analisando o processo 0022314-72.2005.8.26.0451...
# Analisando o processo 0021218-07.2014.8.26.0451...
# Analisando o processo 0018849-55.2005.8.26.0451...
# Analisando o processo 3006831-67.2013.8.26.0451...
# Analisando o processo 0018480-46.2014.8.26.0451...
# Analisando o processo 0004198-66.2015.8.26.0451...
# Analisando o processo 0018541-09.2011.8.26.0451...
# Analisando o processo 0012818-67.2015.8.26.0451...
# Analisando o processo 0019673-96.2014.8.26.0451...
# Analisando o processo 3012030-70.2013.8.26.0451...
# Analisando o processo 0000578-87.2015.8.26.0599...
# Analisando o processo 0012528-52.2015.8.26.0451...
# Analisando o processo 0008882-34.2015.8.26.0451...
# Analisando o processo 3012567-66.2013.8.26.0451...
# Analisando o processo 0000415-10.2015.8.26.0599...
# Analisando o processo 0000393-49.2015.8.26.0599...
# Analisando o processo 0000265-29.2015.8.26.0599...
# Analisando o processo 0024139-85.2004.8.26.0451...
# Analisando o processo 0012372-98.2014.8.26.0451...
# Analisando o processo 0001356-16.2015.8.26.0451...
# Analisando o processo 0009527-59.2015.8.26.0451...
# Analisando o processo 0010441-26.2015.8.26.0451...
# Analisando o processo 0016082-92.2015.8.26.0451...
# Analisando o processo 0004031-83.2014.8.26.0451...
# Analisando o processo 0007030-72.2015.8.26.0451...
# Analisando o processo 0000401-26.2015.8.26.0599...
# Analisando o processo 0010151-11.2015.8.26.0451...
# Analisando o processo 0012320-68.2015.8.26.0451...
# Analisando o processo 0009107-54.2015.8.26.0451...
# Analisando o processo 0000113-37.2015.8.26.0451...
# Analisando o processo 0000181-28.2015.8.26.0599...
# Analisando o processo 0012134-45.2015.8.26.0451...
# Analisando o processo 1500585-53.2025.8.26.0599...
# Analisando o processo 1500719-80.2025.8.26.0599...
# Analisando o processo 0000093-87.2015.8.26.0599...
# Analisando o processo 0000347-60.2015.8.26.0599...
# Analisando o processo 0011929-16.2015.8.26.0451...
# Analisando o processo 0021149-53.2006.8.26.0451...
# Analisando o processo 0019872-21.2014.8.26.0451...
# Analisando o processo 3002223-26.2013.8.26.0451...
# Analisando o processo 0005842-78.2014.8.26.0451...
# Analisando o processo 0007151-03.2015.8.26.0451...
# Analisando o processo 0020121-69.2014.8.26.0451...
# Analisando o processo 0005666-02.2014.8.26.0451...
# Analisando o processo 0009481-46.2010.8.26.0451...
# Analisando o processo 0023097-59.2008.8.26.0451...
# Analisando o processo 0014656-79.2014.8.26.0451...
# Analisando o processo 0010427-13.2013.8.26.0451...
# Analisando o processo 0012437-93.2014.8.26.0451...
# Analisando o processo 3014770-98.2013.8.26.0451...
# Analisando o processo 0004616-04.2015.8.26.0451...
# Analisando o processo 0000278-28.2015.8.26.0599...
# Analisando o processo 0016948-37.2014.8.26.0451...
# Analisando o processo 0004837-84.2015.8.26.0451...
# Analisando o processo 0006289-66.2014.8.26.0451...
# Analisando o processo 0056510-10.2001.8.26.0451...
# Analisando o processo 0024736-20.2005.8.26.0451...
# Analisando o processo 0032050-70.2012.8.26.0451...
# Analisando o processo 3007967-02.2013.8.26.0451...
# Analisando o processo 3004673-39.2013.8.26.0451...
# Analisando o processo 3014771-83.2013.8.26.0451...
# Analisando o processo 3016161-88.2013.8.26.0451...
# Analisando o processo 0007816-87.2013.8.26.0451...
# Analisando o processo 3001254-11.2013.8.26.0451...
# Analisando o processo 3009099-94.2013.8.26.0451...
# Analisando o processo 3014460-92.2013.8.26.0451...
# Analisando o processo 3005575-89.2013.8.26.0451...
# Analisando o processo 3000790-84.2013.8.26.0451...
# Analisando o processo 0014365-79.2014.8.26.0451...
# Analisando o processo 0004341-89.2014.8.26.0451...
# Analisando o processo 0018037-95.2014.8.26.0451...
# Analisando o processo 0012065-47.2014.8.26.0451...
# Analisando o processo 0019540-54.2014.8.26.0451...
# Analisando o processo 0031142-13.2012.8.26.0451...
# Analisando o processo 0017809-23.2014.8.26.0451...
# Analisando o processo 0007199-93.2014.8.26.0451...
# Analisando o processo 0012166-84.2014.8.26.0451...
# Analisando o processo 3011183-68.2013.8.26.0451...
# Analisando o processo 0019701-64.2014.8.26.0451...
# Analisando o processo 0020118-17.2014.8.26.0451...
# Analisando o processo 3011185-38.2013.8.26.0451...
# Analisando o processo 1500551-78.2025.8.26.0599...
# Analisando o processo 1500140-35.2025.8.26.0599...
# Analisando o processo 1506828-40.2023.8.26.0451...
# Analisando o processo 0014199-47.2014.8.26.0451...
# Analisando o processo 0016179-29.2014.8.26.0451...
# Analisando o processo 3015460-30.2013.8.26.0451...
# Analisando o processo 0002378-46.2014.8.26.0451...
# Analisando o processo 0013096-05.2014.8.26.0451...
# Analisando o processo 0012584-22.2014.8.26.0451...
# Analisando o processo 0006963-44.2014.8.26.0451...
# Analisando o processo 0015835-48.2014.8.26.0451...
# Analisando o processo 0001925-51.2014.8.26.0451...
# Analisando o processo 0019097-06.2014.8.26.0451...
# Analisando o processo 0019552-68.2014.8.26.0451...
# Analisando o processo 0007890-10.2014.8.26.0451...
# Analisando o processo 3003975-33.2013.8.26.0451...
# Analisando o processo 0002694-59.2014.8.26.0451...
# Analisando o processo 0006343-32.2014.8.26.0451...
# Analisando o processo 3008008-66.2013.8.26.0451...
# Analisando o processo 0007886-70.2014.8.26.0451...
# Analisando o processo 0009926-25.2014.8.26.0451...
# Analisando o processo 0013575-95.2014.8.26.0451...
# Analisando o processo 0009472-45.2014.8.26.0451...
# Analisando o processo 0014883-40.2012.8.26.0451...
# Analisando o processo 0009658-68.2014.8.26.0451...
# Analisando o processo 0004447-51.2014.8.26.0451...
# Analisando o processo 0028354-26.2012.8.26.0451...
# Analisando o processo 0008651-41.2014.8.26.0451...
# Analisando o processo 0003360-60.2014.8.26.0451...
# Analisando o processo 0028169-66.2004.8.26.0451...
# Analisando o processo 0003358-90.2014.8.26.0451...
# Analisando o processo 0007450-14.2014.8.26.0451...
# Analisando o processo 0035455-51.2011.8.26.0451...
# Analisando o processo 0004030-98.2014.8.26.0451...
# Analisando o processo 0030044-90.2012.8.26.0451...
# Analisando o processo 0001323-94.2013.8.26.0451...
# Analisando o processo 0002658-51.2013.8.26.0451...
# Analisando o processo 0032362-51.2009.8.26.0451...
# Analisando o processo 0006861-56.2013.8.26.0451...
# Analisando o processo 0002565-88.2013.8.26.0451...
# Analisando o processo 0056324-55.1999.8.26.0451...
# Analisando o processo 0021022-08.2012.8.26.0451...
# Analisando o processo 0006819-07.2013.8.26.0451...
# Analisando o processo 0000057-38.2014.8.26.0451...
# Analisando o processo 3010836-35.2013.8.26.0451...
# Analisando o processo 3008564-68.2013.8.26.0451...
# Analisando o processo 3002860-74.2013.8.26.0451...
# Analisando o processo 3002733-39.2013.8.26.0451...
# Analisando o processo 0001726-29.2014.8.26.0451...
# Analisando o processo 0028736-19.2012.8.26.0451...
# Analisando o processo 0023503-75.2011.8.26.0451...
# Analisando o processo 0001045-59.2014.8.26.0451...
# Analisando o processo 3014239-12.2013.8.26.0451...
# Analisando o processo 3008162-84.2013.8.26.0451...
# Analisando o processo 0034089-40.2012.8.26.0451...
# Analisando o processo 3012661-14.2013.8.26.0451...
# Analisando o processo 0032383-03.2004.8.26.0451...
# Analisando o processo 3006084-20.2013.8.26.0451...
# Analisando o processo 3000652-20.2013.8.26.0451...
# Analisando o processo 0002342-04.2014.8.26.0451...
# Analisando o processo 3010088-03.2013.8.26.0451...
# Analisando o processo 0014938-88.2012.8.26.0451...
# Analisando o processo 0033560-21.2012.8.26.0451...
# Analisando o processo 0031892-15.2012.8.26.0451...
# Analisando o processo 0035322-09.2011.8.26.0451...
# Analisando o processo 0024650-05.2012.8.26.0451...
# Analisando o processo 0019956-90.2012.8.26.0451...
# Analisando o processo 0027579-11.2012.8.26.0451...
# Analisando o processo 0032803-27.2012.8.26.0451...
# Analisando o processo 1508775-32.2023.8.26.0451...
# Analisando o processo 0003131-51.2024.8.26.0451...
# Analisando o processo 3001675-98.2013.8.26.0451...
# Analisando o processo 3005743-91.2013.8.26.0451...
# Analisando o processo 0034554-49.2012.8.26.0451...
# Analisando o processo 0012616-95.2012.8.26.0451...
# Analisando o processo 0006821-74.2013.8.26.0451...
# Analisando o processo 3002859-89.2013.8.26.0451...
# Analisando o processo 0028141-98.2004.8.26.0451...
# Analisando o processo 3007637-05.2013.8.26.0451...
# Analisando o processo 0000045-58.2013.8.26.0451...
# Analisando o processo 0004302-63.2012.8.26.0451...
# Analisando o processo 3009100-79.2013.8.26.0451...
# Analisando o processo 0022570-68.2012.8.26.0451...
# Analisando o processo 3003853-20.2013.8.26.0451...
# Analisando o processo 0033377-84.2011.8.26.0451...
# Analisando o processo 0001672-39.2009.8.26.0451...
# Analisando o processo 3000651-35.2013.8.26.0451...
# Analisando o processo 0030399-03.2012.8.26.0451...
# Analisando o processo 3006990-10.2013.8.26.0451...
# Analisando o processo 3010625-96.2013.8.26.0451...
# Analisando o processo 0030263-45.2008.8.26.0451...
# Analisando o processo 3005740-39.2013.8.26.0451...
# Analisando o processo 3003592-55.2013.8.26.0451...
# Analisando o processo 0009941-96.2011.8.26.0451...
# Analisando o processo 0013654-50.2009.8.26.0451...
# Analisando o processo 0010058-19.2013.8.26.0451...
# Analisando o processo 0031027-26.2011.8.26.0451...
# Analisando o processo 3004641-34.2013.8.26.0451...
# Analisando o processo 3002304-72.2013.8.26.0451...
# Analisando o processo 0036112-56.2012.8.26.0451...
# Analisando o processo 0024434-44.2012.8.26.0451...
# Analisando o processo 3004388-46.2013.8.26.0451...
# Analisando o processo 3001924-49.2013.8.26.0451...
# Analisando o processo 3002539-39.2013.8.26.0451...
# Analisando o processo 0000545-95.2011.8.26.0451...
# Analisando o processo 0003834-65.2013.8.26.0451...
# Analisando o processo 0010102-38.2013.8.26.0451...
# Analisando o processo 0009245-89.2013.8.26.0451...
# Analisando o processo 0028321-36.2012.8.26.0451...
# Analisando o processo 0031146-50.2012.8.26.0451...
# Analisando o processo 0001135-72.2011.8.26.0451...
# Analisando o processo 0003839-87.2013.8.26.0451...
# Analisando o processo 3000685-10.2013.8.26.0451...
# Analisando o processo 0015165-78.2012.8.26.0451...
# Analisando o processo 0024375-90.2011.8.26.0451...
# Analisando o processo 1501373-67.2025.8.26.0599...
# Analisando o processo 3005211-20.2013.8.26.0451...
# Analisando o processo 1501035-93.2025.8.26.0599...
# Analisando o processo 0031404-60.2012.8.26.0451...
# Analisando o processo 0023728-61.2012.8.26.0451...
# Analisando o processo 0024645-80.2012.8.26.0451...
# Analisando o processo 0028320-51.2012.8.26.0451...
# Analisando o processo 0018436-32.2011.8.26.0451...
# Analisando o processo 0035875-22.2012.8.26.0451...
# Analisando o processo 0034197-40.2010.8.26.0451...
# Analisando o processo 0003859-49.2011.8.26.0451...
# Analisando o processo 0027445-52.2010.8.26.0451...
# Analisando o processo 1501396-81.2023.8.26.0599...
# Analisando o processo 1500186-24.2025.8.26.0599...
# Analisando o processo 1500739-08.2024.8.26.0599...
# Analisando o processo 1501403-78.2020.8.26.0599...
# Analisando o processo 1500002-68.2025.8.26.0599...
# Analisando o processo 1500688-94.2024.8.26.0599...
# Analisando o processo 1501176-88.2020.8.26.0599...
# Analisando o processo 1502016-59.2024.8.26.0599...
# Analisando o processo 1501246-66.2024.8.26.0599...
# Analisando o processo 1500938-64.2023.8.26.0599...
# Analisando o processo 1502132-65.2024.8.26.0599...
# Analisando o processo 1502199-30.2024.8.26.0599...
# Analisando o processo 1501810-45.2024.8.26.0599...
# Analisando o processo 1501974-10.2024.8.26.0599...
# Analisando o processo 1502048-64.2024.8.26.0599...
# Analisando o processo 1501899-68.2024.8.26.0599...
# Analisando o processo 1501745-50.2024.8.26.0599...
# Analisando o processo 1501603-46.2024.8.26.0599...
# Analisando o processo 1501804-38.2024.8.26.0599...
# Analisando o processo 1501692-69.2024.8.26.0599...
# Analisando o processo 1501059-92.2023.8.26.0599...
# Analisando o processo 1547138-93.2020.8.26.0451...
# Analisando o processo 1501116-76.2024.8.26.0599...
# Analisando o processo 1501426-17.2019.8.26.0451...
# Analisando o processo 1502588-49.2023.8.26.0599...
# Analisando o processo 1500945-22.2024.8.26.0599...
# Analisando o processo 0007191-04.2023.8.26.0451...
# Analisando o processo 1501800-98.2024.8.26.0599...
# Analisando o processo 1500563-97.2022.8.26.0599...
# Analisando o processo 1502190-68.2024.8.26.0599...
# Analisando o processo 1502330-39.2023.8.26.0599...
# Analisando o processo 1501922-14.2024.8.26.0599...
# Analisando o processo 0001479-62.2025.8.26.0451...
# Analisando o processo 1500839-60.2024.8.26.0599...
# Analisando o processo 1500834-14.2019.8.26.0599...
# Analisando o processo 1502052-38.2023.8.26.0599...
# Analisando o processo 1501703-98.2024.8.26.0599...
# Analisando o processo 1501651-05.2024.8.26.0599...
# Analisando o processo 1501686-33.2022.8.26.0599...
# Analisando o processo 1501621-67.2024.8.26.0599...
# Analisando o processo 1501755-94.2024.8.26.0599...
# Analisando o processo 1502089-92.2021.8.26.0451...
# Analisando o processo 1501384-33.2024.8.26.0599...
# Analisando o processo 1501131-45.2024.8.26.0599...
# Analisando o processo 1500422-10.2024.8.26.0599...
# Analisando o processo 1501236-22.2024.8.26.0599...
# Analisando o processo 1501906-60.2024.8.26.0599...
# Analisando o processo 1500948-72.2020.8.26.0451...
# Analisando o processo 1501928-21.2024.8.26.0599...
# Analisando o processo 1501629-44.2024.8.26.0599...
# Analisando o processo 1502063-67.2023.8.26.0599...
# Analisando o processo 1501119-31.2024.8.26.0599...
# Analisando o processo 1501507-31.2024.8.26.0599...
# Analisando o processo 1501781-92.2024.8.26.0599...
# Analisando o processo 1501836-43.2024.8.26.0599...
# Analisando o processo 1500630-28.2023.8.26.0599...
# Analisando o processo 1501740-28.2024.8.26.0599...
# Analisando o processo 1501031-27.2023.8.26.0599...
# Analisando o processo 1500328-96.2023.8.26.0599...
# Analisando o processo 1501691-84.2024.8.26.0599...
# Analisando o processo 1500568-22.2022.8.26.0599...
# Analisando o processo 1501893-95.2023.8.26.0599...
# Analisando o processo 1501796-95.2023.8.26.0599...
# Analisando o processo 1501637-21.2024.8.26.0599...
# Analisando o processo 1501561-94.2024.8.26.0599...
# Analisando o processo 1500808-06.2025.8.26.0599...
# Analisando o processo 1500941-48.2025.8.26.0599...
# Analisando o processo 1502127-77.2023.8.26.0599...
# Analisando o processo 0010400-44.2024.8.26.0451...
# Analisando o processo 0011711-07.2023.8.26.0451...
# Analisando o processo 1500006-42.2024.8.26.0599...
# Analisando o processo 1500759-33.2023.8.26.0599...
# Analisando o processo 0010810-05.2024.8.26.0451...
# Analisando o processo 1501345-36.2024.8.26.0599...
# Analisando o processo 1501724-79.2021.8.26.0599...
# Analisando o processo 1501023-16.2024.8.26.0599...
# Analisando o processo 1500847-37.2024.8.26.0599...
# Analisando o processo 1501066-50.2024.8.26.0599...
# Analisando o processo 1500852-59.2024.8.26.0599...
# Analisando o processo 1501161-80.2024.8.26.0599...
# Analisando o processo 1501023-84.2022.8.26.0599...
# Analisando o processo 1502315-70.2023.8.26.0599...
# Analisando o processo 1501257-95.2024.8.26.0599...
# Analisando o processo 1501157-43.2024.8.26.0599...
# Analisando o processo 1500973-53.2025.8.26.0599...
# Analisando o processo 1502211-78.2023.8.26.0599...
# Analisando o processo 1505836-11.2025.8.26.0451...
# Analisando o processo 1501782-14.2023.8.26.0599...
# Analisando o processo 1502000-42.2023.8.26.0599...
# Analisando o processo 1500205-64.2024.8.26.0599...
# Analisando o processo 1500820-54.2024.8.26.0599...
# Analisando o processo 1500907-10.2024.8.26.0599...
# Analisando o processo 1501213-76.2024.8.26.0599...
# Analisando o processo 1500902-85.2024.8.26.0599...
# Analisando o processo 1501156-58.2024.8.26.0599...
# Analisando o processo 1500486-20.2024.8.26.0599...
# Analisando o processo 1501248-36.2024.8.26.0599...
# Analisando o processo 1500959-06.2024.8.26.0599...
# Analisando o processo 0000218-50.2018.8.26.0599...
# Analisando o processo 1500132-92.2024.8.26.0599...
# Analisando o processo 1500582-35.2024.8.26.0599...
# Analisando o processo 1500697-56.2024.8.26.0599...
# Analisando o processo 1500590-12.2024.8.26.0599...
# Analisando o processo 0006302-16.2024.8.26.0451...
# Analisando o processo 1500528-69.2024.8.26.0599...
# Analisando o processo 1500198-72.2024.8.26.0599...
# Analisando o processo 1500734-54.2022.8.26.0599...
# Analisando o processo 1500838-75.2024.8.26.0599...
# Analisando o processo 1501050-96.2024.8.26.0599...
# Analisando o processo 1500398-79.2024.8.26.0599...
# Analisando o processo 1501036-78.2025.8.26.0599...
# Analisando o processo 1501200-43.2025.8.26.0599...
# Analisando o processo 1501651-68.2025.8.26.0599...
# Analisando o processo 0026733-72.2004.8.26.0451...
# Analisando o processo 1500760-81.2024.8.26.0599...
# Analisando o processo 1500229-92.2024.8.26.0599...
# Analisando o processo 0006380-10.2024.8.26.0451...
# Analisando o processo 1500459-37.2024.8.26.0599...
# Analisando o processo 1502256-82.2023.8.26.0599...
# Analisando o processo 1500434-24.2024.8.26.0599...
# Analisando o processo 1500556-37.2024.8.26.0599...
# Analisando o processo 1501607-20.2023.8.26.0599...
# Analisando o processo 1500571-06.2024.8.26.0599...
# Analisando o processo 1500336-39.2024.8.26.0599...
# Analisando o processo 1500265-37.2024.8.26.0599...
# Analisando o processo 1500034-10.2024.8.26.0599...
# Analisando o processo 0003276-10.2024.8.26.0451...
# Analisando o processo 1500082-37.2022.8.26.0599...
# Analisando o processo 1501591-03.2022.8.26.0599...
# Analisando o processo 1500606-97.2023.8.26.0599...
# Analisando o processo 1502319-10.2023.8.26.0599...
# Analisando o processo 1502474-13.2023.8.26.0599...
# Analisando o processo 1502477-65.2023.8.26.0599...
# Analisando o processo 1501573-84.2019.8.26.0599...
# Analisando o processo 1501614-12.2023.8.26.0599...
# Analisando o processo 1500474-06.2024.8.26.0599...
# Analisando o processo 1500590-75.2025.8.26.0599...
# Analisando o processo 1502532-16.2023.8.26.0599...
# Analisando o processo 0072066-81.2003.8.26.0451...
# Analisando o processo 1501260-84.2023.8.26.0599...
# Analisando o processo 1500598-23.2023.8.26.0599...
# Analisando o processo 1500899-67.2023.8.26.0599...
# Analisando o processo 1502301-86.2023.8.26.0599...
# Analisando o processo 0009667-15.2023.8.26.0451...
# Analisando o processo 0001087-98.2020.8.26.0451...
# Analisando o processo 1501425-34.2023.8.26.0599...
# Analisando o processo 1500576-96.2022.8.26.0599...
# Analisando o processo 1502104-34.2023.8.26.0599...
# Analisando o processo 1502189-20.2023.8.26.0599...
# Analisando o processo 1501512-87.2023.8.26.0599...
# Analisando o processo 1500247-50.2023.8.26.0599...
# Analisando o processo 1500163-54.2020.8.26.0599...
# Analisando o processo 1501487-79.2020.8.26.0599...
# Analisando o processo 1501098-60.2021.8.26.0599...
# Analisando o processo 1501351-77.2023.8.26.0599...
# Analisando o processo 1500841-64.2023.8.26.0599...

# %%
# Cria um DataFrame a partir da lista de respostas
# A lista_de_respostas contém tuplas (numero_do_processo, dict_analise)
# Vamos expandir o dicionário em colunas do DataFrame

data_para_df = []
for numero_processo, analise_dict in lista_de_respostas:
  row_data = {'numero_do_processo': numero_processo}
  row_data.update(analise_dict) # Adiciona as chaves do dicionário como colunas
  data_para_df.append(row_data)

# %%
df_respostas = pd.DataFrame(data_para_df)
display(df_respostas.head(5))

df_respostas.to_csv(CSV_SENTENCAS_ANALISADAS, index=False, encoding='utf-8-sig')
print(f"Arquivo CSV salvo em: {CSV_SENTENCAS_ANALISADAS}")
# Out:
#           numero_do_processo      data_fato quantidade_reus  \
# 0  1501551-84.2023.8.26.0599  Não se aplica               1
# 1  1500825-76.2024.8.26.0599     03/05/2024               1
# 2  1501156-92.2023.8.26.0599     31/05/2023               1
# 3  1501774-03.2024.8.26.0599     25/10/2024               3
# 4  1500518-25.2024.8.26.0599     13/03/2024               1
#
#                                        endereco_fato      responsavel_prisao  \
# 0                                      Não se aplica           Não se aplica
# 1  Rua Querubim Sampaio, próximo ao nº 1, bairro ...        policial militar
# 2  Rua do Enxofre, 963, bairro Enxofre, Piracicab...  guarda civil municipal
# 3               Rua Lins, 288, Itapuã, Piracicaba/SP        policial militar
# 4  Rua Campos Sales, 680, apto 212, Bairro São Ju...          policial civil
#
#                                   modus_operandi_reu  \
# 0  Tráfico realizado com venda de entorpecentes e...
# 1  R.C., em conluio com o menor A.B.B., aproximou...
# 2  Em via pública, na região conhecida pelo tráfi...
# 3  Em via pública, com unidade de desígnios, os r...
# 4  Guardava entorpecentes para tráfico, com porçõ...
#
#                                         alegacao_reu resultado_processo  \
# 0                                      Não se aplica         Procedente
# 1  A defesa sustenta absolvição por insuficiência...         Procedente
# 2  A defesa pleiteou a absolvição ou a desclassif...         Procedente
# 3  A defesa alegou ausência de prova suficiente d...         Procedente
# 4  Preliminar: nulidade da prova obtida com acess...         Procedente
#
#                                      resumo_sentenca
# 0  Resumo da sentença: Ação de tráfico de drogas ...
# 1  Trata-se de ação penal por tráfico de drogas c...
# 2  O.J.S. foi condenado pela prática de tráfico d...
# 3  Julgo procedente a ação e condeno JAFDS e CALD...
# 4  Julgando procedente a denúncia, o juízo conden...
# Arquivo CSV salvo em: dados\sentencas_analisadas.csv

# %%
df_geral = pd.merge(df_1, df_respostas, on='numero_do_processo')
df_geral.head(5)
# Out:
#           numero_do_processo                                    classe  \
# 0  1501551-84.2023.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 1  1500825-76.2024.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 2  1501156-92.2023.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 3  1501774-03.2024.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 4  1500518-25.2024.8.26.0599  Procedimento Especial da Lei Antitóxicos
#
#                               assunto     comarca                foro  \
# 0  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 1  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 2  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 3  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 4  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
#
#                vara data_de_disponibilização  \
# 0  3ª Vara Criminal               07/01/2026
# 1  4ª Vara Criminal               05/01/2026
# 2  4ª Vara Criminal               29/12/2025
# 3  3ª Vara Criminal               19/12/2025
# 4  1ª Vara Criminal               17/12/2025
#
#                                             sentenca  \
# 0  SENTENÇA\n\nProcesso Digital nº:\t1501551-84.2...
# 1  SENTENÇA\n\nProcesso Digital nº:\t1500825-76.2...
# 2  SENTENÇA\n\nProcesso Digital nº:\t1501156-92.2...
# 3  SENTENÇA\n\nProcesso Digital nº:\t1501774-03.2...
# 4  SENTENÇA\n\nProcesso Digital nº:\t1500518-25.2...
#
#                         magistrado      data_fato quantidade_reus  \
# 0          Rodrigo Pares Andreucci  Não se aplica               1
# 1    GABRIELA DE ALMEIDA VERGUEIRO     03/05/2024               1
# 2    GABRIELA DE ALMEIDA VERGUEIRO     31/05/2023               1
# 3          Rodrigo Pares Andreucci     25/10/2024               3
# 4  Ana Claudia Madeira de Oliveira     13/03/2024               1
#
#                                        endereco_fato      responsavel_prisao  \
# 0                                      Não se aplica           Não se aplica
# 1  Rua Querubim Sampaio, próximo ao nº 1, bairro ...        policial militar
# 2  Rua do Enxofre, 963, bairro Enxofre, Piracicab...  guarda civil municipal
# 3               Rua Lins, 288, Itapuã, Piracicaba/SP        policial militar
# 4  Rua Campos Sales, 680, apto 212, Bairro São Ju...          policial civil
#
#                                   modus_operandi_reu  \
# 0  Tráfico realizado com venda de entorpecentes e...
# 1  R.C., em conluio com o menor A.B.B., aproximou...
# 2  Em via pública, na região conhecida pelo tráfi...
# 3  Em via pública, com unidade de desígnios, os r...
# 4  Guardava entorpecentes para tráfico, com porçõ...
#
#                                         alegacao_reu resultado_processo  \
# 0                                      Não se aplica         Procedente
# 1  A defesa sustenta absolvição por insuficiência...         Procedente
# 2  A defesa pleiteou a absolvição ou a desclassif...         Procedente
# 3  A defesa alegou ausência de prova suficiente d...         Procedente
# 4  Preliminar: nulidade da prova obtida com acess...         Procedente
#
#                                      resumo_sentenca
# 0  Resumo da sentença: Ação de tráfico de drogas ...
# 1  Trata-se de ação penal por tráfico de drogas c...
# 2  O.J.S. foi condenado pela prática de tráfico d...
# 3  Julgo procedente a ação e condeno JAFDS e CALD...
# 4  Julgando procedente a denúncia, o juízo conden...

# %%
df_geral_com_endereco = df_geral[df_geral['endereco_fato'] != 'Não se aplica']
df_geral_com_endereco.head(5)

df_geral_com_endereco.to_csv(CSV_SENTENCAS_COM_ENDERECOS, index=False, encoding='utf-8-sig')
print(f"Arquivo CSV salvo em: {CSV_SENTENCAS_COM_ENDERECOS}")
# Out:
# Arquivo CSV salvo em: dados\sentencas_com_enderecos.csv

# %% [markdown]
# # Georreferenciamento do dataframe

# %%
def buscar_coords(endereco, api_key):
    """Função auxiliar para retornar latitude e longitude ou None em caso de erro."""
    if not endereco:
        return None, None

    url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {"address": endereco, "key": api_key, "language": "pt-BR"}

    try:
        response = requests.get(url, params=params)
        data = response.json()

        if data.get("status") == "OK":
            location = data["results"][0]["geometry"]["location"]
            return location["lat"], location["lng"]
        else:
            return None, None
    except:
        return None, None

# %%
df_geral_com_endereco[['latitude', 'longitude']] = df_geral_com_endereco['endereco_fato'].apply(
    lambda x: pd.Series(buscar_coords(x, GOOGLE_API_KEY))
)
# Out:
# C:\Users\jepim\AppData\Local\Temp\ipykernel_6780\74596199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geral_com_endereco[['latitude', 'longitude']] = df_geral_com_endereco['endereco_fato'].apply(
# C:\Users\jepim\AppData\Local\Temp\ipykernel_6780\74596199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geral_com_endereco[['latitude', 'longitude']] = df_geral_com_endereco['endereco_fato'].apply(

# %%
df_geral_com_endereco.head(5)
# Out:
#           numero_do_processo                                    classe  \
# 1  1500825-76.2024.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 2  1501156-92.2023.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 3  1501774-03.2024.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 4  1500518-25.2024.8.26.0599  Procedimento Especial da Lei Antitóxicos
# 5  1501896-79.2025.8.26.0599  Procedimento Especial da Lei Antitóxicos
#
#                               assunto     comarca                foro  \
# 1  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 2  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 3  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 4  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
# 5  Tráfico de Drogas e Condutas Afins  Piracicaba  Foro de Piracicaba
#
#                vara data_de_disponibilização  \
# 1  4ª Vara Criminal               05/01/2026
# 2  4ª Vara Criminal               29/12/2025
# 3  3ª Vara Criminal               19/12/2025
# 4  1ª Vara Criminal               17/12/2025
# 5  4ª Vara Criminal               17/12/2025
#
#                                             sentenca  \
# 1  SENTENÇA\n\nProcesso Digital nº:\t1500825-76.2...
# 2  SENTENÇA\n\nProcesso Digital nº:\t1501156-92.2...
# 3  SENTENÇA\n\nProcesso Digital nº:\t1501774-03.2...
# 4  SENTENÇA\n\nProcesso Digital nº:\t1500518-25.2...
# 5  SENTENÇA\n\nProcesso Digital nº:\t1501896-79.2...
#
#                         magistrado   data_fato quantidade_reus  \
# 1    GABRIELA DE ALMEIDA VERGUEIRO  03/05/2024               1
# 2    GABRIELA DE ALMEIDA VERGUEIRO  31/05/2023               1
# 3          Rodrigo Pares Andreucci  25/10/2024               3
# 4  Ana Claudia Madeira de Oliveira  13/03/2024               1
# 5                     Gisela Ruffo  09/08/2025               3
#
#                                        endereco_fato      responsavel_prisao  \
# 1  Rua Querubim Sampaio, próximo ao nº 1, bairro ...        policial militar
# 2  Rua do Enxofre, 963, bairro Enxofre, Piracicab...  guarda civil municipal
# 3               Rua Lins, 288, Itapuã, Piracicaba/SP        policial militar
# 4  Rua Campos Sales, 680, apto 212, Bairro São Ju...          policial civil
# 5             Rua Jumirim, 161, Matão, Piracicaba/SP        policial militar
#
#                                   modus_operandi_reu  \
# 1  R.C., em conluio com o menor A.B.B., aproximou...
# 2  Em via pública, na região conhecida pelo tráfi...
# 3  Em via pública, com unidade de desígnios, os r...
# 4  Guardava entorpecentes para tráfico, com porçõ...
# 5  RPO, DDC e LFP atuavam conjuntamente no endere...
#
#                                         alegacao_reu resultado_processo  \
# 1  A defesa sustenta absolvição por insuficiência...         Procedente
# 2  A defesa pleiteou a absolvição ou a desclassif...         Procedente
# 3  A defesa alegou ausência de prova suficiente d...         Procedente
# 4  Preliminar: nulidade da prova obtida com acess...         Procedente
# 5  DDC confessou a prática. RPO e LFP negaram env...         Procedente
#
#                                      resumo_sentenca   latitude  longitude
# 1  Trata-se de ação penal por tráfico de drogas c... -22.745242 -47.675811
# 2  O.J.S. foi condenado pela prática de tráfico d... -22.744447 -47.656967
# 3  Julgo procedente a ação e condeno JAFDS e CALD... -22.753135 -47.661101
# 4  Julgando procedente a denúncia, o juízo conden... -22.717498 -47.645577
# 5  Condenação de três réus por tráfico de drogas ... -22.748460 -47.671598

# %%
# Salvar o DataFrame georreferenciado em um novo arquivo CSV
df_geral_com_endereco.to_csv(CSV_SENTENCAS_GEORREFERENCIADAS, index=False, encoding='utf-8-sig')
print(f"DataFrame de respostas salvo em: {CSV_SENTENCAS_GEORREFERENCIADAS}")
# Out:
# DataFrame de respostas salvo em: dados\sentencas_georreferenciadas.csv

# %%
# Cálculo dos limites min/max para latitude e longitude
min_lat = min(PONTO_1[0], PONTO_2[0])
max_lat = max(PONTO_1[0], PONTO_2[0])
min_lon = min(PONTO_1[1], PONTO_2[1])
max_lon = max(PONTO_1[1], PONTO_2[1])

# Filtragem dos dados dentro do retângulo
df_geral_com_endereco_filtrado = df_geral_com_endereco[
    (df_geral_com_endereco['latitude'] >= min_lat) & (df_geral_com_endereco['latitude'] <= max_lat) &
    (df_geral_com_endereco['longitude'] >= min_lon) & (df_geral_com_endereco['longitude'] <= max_lon)
    ]

# %%
# Gera o arquivo para a visualização
df_geral_com_endereco_filtrado[['numero_do_processo', 'data_fato', 'responsavel_prisao', 'modus_operandi_reu', 
                       'alegacao_reu', 'resultado_processo', 'resumo_sentenca', 'latitude', 'longitude']].to_csv(
    'dados.csv', index=False, encoding='utf-8-sig')
